# %% [markdown]
# # Filling Area on Line Plots

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('data1.csv')

# %%
df.head()
# Out:
#    Age  All_Devs  Python  JavaScript  Unnamed: 4  Unnamed: 5
# 0   18     17784   20046       16446         NaN         NaN
# 1   19     16500   17100       16791         NaN         NaN
# 2   20     18012   20000       18942         NaN         NaN
# 3   21     20628   24744       21780         NaN         NaN
# 4   22     25206   30500       25704         NaN         NaN

# %%
# %matplotlib inline

# %%
ages=df['Age']
dev_salaries=df['All_Devs']
py_salaries=df['Python']
js_salaries=df['JavaScript']

plt.plot(ages,dev_salaries,color='#444444',linestyle='--',label='All Devs')
plt.plot(ages,py_salaries,label='Python')

plt.title('Median salary (USD) by age')
plt.xlabel('Ages')
plt.ylabel('Median salary (USD)')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Filling areas below the graph of python

# %%
ages=df['Age']
dev_salaries=df['All_Devs']
py_salaries=df['Python']
js_salaries=df['JavaScript']

plt.plot(ages,dev_salaries,color='#444444',linestyle='--',label='All Devs')
plt.plot(ages,py_salaries,label='Python')

plt.title('Median salary (USD) by age')
plt.xlabel('Ages')
plt.ylabel('Median salary (USD)')
plt.legend()
plt.tight_layout()
plt.fill_between(ages,py_salaries)
plt.show()

# %%
ages=df['Age']
dev_salaries=df['All_Devs']
py_salaries=df['Python']
js_salaries=df['JavaScript']

plt.plot(ages,dev_salaries,color='#444444',linestyle='--',label='All Devs')
plt.plot(ages,py_salaries,label='Python')

plt.title('Median salary (USD) by age')
plt.xlabel('Ages')
plt.ylabel('Median salary (USD)')
plt.legend()
plt.tight_layout()
plt.fill_between(ages,py_salaries,alpha=0.25)
plt.show()

# %% [markdown]
# adding alpha value

# %%
ages=df['Age']
dev_salaries=df['All_Devs']
py_salaries=df['Python']
js_salaries=df['JavaScript']

overall_median= 57287
plt.plot(ages,dev_salaries,color='#444444',linestyle='--',label='All Devs')
plt.plot(ages,py_salaries,label='Python')

plt.title('Median salary (USD) by age')
plt.xlabel('Ages')
plt.ylabel('Median salary (USD)')
plt.legend()
plt.tight_layout()
plt.fill_between(ages,py_salaries,overall_median,alpha=0.25,
                 where=(py_salaries>overall_median),interpolate=True)
plt.fill_between(ages,py_salaries,overall_median,alpha=0.25,
                 where=(py_salaries<=overall_median),color='red',interpolate=True)
plt.show()

# %%
ages=df['Age']
dev_salaries=df['All_Devs']
py_salaries=df['Python']
js_salaries=df['JavaScript']

overall_median= 57287
plt.plot(ages,dev_salaries,color='#444444',linestyle='--',label='All Devs')
plt.plot(ages,py_salaries,label='Python')

plt.title('Median salary (USD) by age')
plt.xlabel('Ages')
plt.ylabel('Median salary (USD)')

plt.tight_layout()
plt.fill_between(ages,py_salaries,dev_salaries,alpha=0.25,
                 where=(py_salaries>dev_salaries),interpolate=True,label='Above avg')
plt.fill_between(ages,py_salaries,dev_salaries,alpha=0.25,
                 where=(py_salaries<=dev_salaries),color='red',interpolate=True,label='Below avg')
plt.legend()
plt.show()
